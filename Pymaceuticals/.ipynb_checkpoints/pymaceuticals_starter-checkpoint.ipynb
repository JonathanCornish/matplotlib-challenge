# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load 
mouse_drug_data_to_csv = "data/mouse_drug_data.csv"
clinical_trial_data_to_csv = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv("data/mouse_drug_data.csv")
mouse_df.head()
clinical_df = pd.read_csv("data/clinicaltrial_data.csv")
clinical_df.head()
# Combine the data into a single dataset
combined_df = pd.merge(mouse_df, clinical_df, on="Mouse ID", how="outer")
# combined_df.groupby(["Timepoint"])

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
# Convert to DataFrame

grouped_df = combined_df.groupby(["Drug", "Timepoint"])
tumor_vol_df = grouped_df.mean().reset_index()


# Preview DataFrame
tumor_vol_df.head(15)
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0   Capomulin          0           45.000000          0.000000
# 1   Capomulin          5           44.266086          0.160000
# 2   Capomulin         10           43.084291          0.320000
# 3   Capomulin         15           42.064317          0.375000
# 4   Capomulin         20           40.716325          0.652174
# 5   Capomulin         25           39.939528          0.818182
# 6   Capomulin         30           38.769339          1.090909
# 7   Capomulin         35           37.816839          1.181818
# 8   Capomulin         40           36.958001          1.380952
# 9   Capomulin         45           36.236114          1.476190
# 10   Ceftamin          0           45.000000          0.000000
# 11   Ceftamin          5           46.503051          0.380952
# 12   Ceftamin         10           48.285125          0.600000
# 13   Ceftamin         15           50.094055          0.789474
# ...

# %%
tumor_vol_df = tumor_vol_df.loc[:,["Drug","Timepoint","Tumor Volume (mm3)"]]
tumor_vol_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
tumor_vol_df.reset_index()
# Out:
#     index       Drug  Timepoint  Tumor Volume (mm3)
# 0       0  Capomulin          0           45.000000
# 1       1  Capomulin          5           44.266086
# 2       2  Capomulin         10           43.084291
# 3       3  Capomulin         15           42.064317
# 4       4  Capomulin         20           40.716325
# ..    ...        ...        ...                 ...
# 95     95  Zoniferol         25           55.432935
# 96     96  Zoniferol         30           57.713531
# 97     97  Zoniferol         35           60.089372
# 98     98  Zoniferol         40           62.916692
# 99     99  Zoniferol         45           65.960888
#
# [100 rows x 4 columns]

# %%
# # Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

vol_sem = pd.DataFrame(combined_df.groupby(["Drug", "Timepoint"]).sem()["Tumor Volume (mm3)"])
vol_sem.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
vol_sem.reset_index()
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
dm_df = tumor_vol_df.pivot(index="Timepoint", columns="Drug")

# Preview that Reformatting worked
dm_df.head()
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000
# 5          47.125589  47.248967  43.944859  47.527452  46.851818
# 10         49.423329  49.101541  42.531957  49.463844  48.689881
# 15         51.359742  51.067318  41.495061  51.529409  50.779059
# 20         54.364417  53.346737  40.238325  54.067395  53.170334

# %%
# the .shape method on the dataframe tells you the shape of the data i.e. the number of rows by the number of columns
# 

combined_df["Timepoint"].shape
tumor_vol_df["Tumor Volume (mm3)"].shape
# Out:
# (100,)

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots()
ax.errorbar(tumor_vol_df["Timepoint"], tumor_vol_df["Tumor Volume (mm3)"], yerr=vol_sem["Tumor Volume (mm3)"])



# do a loc to get the only ones that I want
# Save the Figure

# plt.show()
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
m_grouped_df = combined_df.groupby(["Drug", "Timepoint"])
m_df = m_grouped_df.mean().reset_index()
# Convert to DataFrame

# Preview DataFrame
m_df.head()
# m_df.columns
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0  Capomulin          0           45.000000          0.000000
# 1  Capomulin          5           44.266086          0.160000
# 2  Capomulin         10           43.084291          0.320000
# 3  Capomulin         15           42.064317          0.375000
# 4  Capomulin         20           40.716325          0.652174

# %%
ms_df = m_df.loc[:,["Metastatic Sites"]]
ms_df.head()
# Out:
#    Metastatic Sites
# 0          0.000000
# 1          0.160000
# 2          0.320000
# 3          0.375000
# 4          0.652174

# %%
m_df.reset_index()
# Out:
#     index       Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0       0  Capomulin          0           45.000000          0.000000
# 1       1  Capomulin          5           44.266086          0.160000
# 2       2  Capomulin         10           43.084291          0.320000
# 3       3  Capomulin         15           42.064317          0.375000
# 4       4  Capomulin         20           40.716325          0.652174
# ..    ...        ...        ...                 ...               ...
# 95     95  Zoniferol         25           55.432935          1.687500
# 96     96  Zoniferol         30           57.713531          1.933333
# 97     97  Zoniferol         35           60.089372          2.285714
# 98     98  Zoniferol         40           62.916692          2.785714
# 99     99  Zoniferol         45           65.960888          3.071429
#
# [100 rows x 5 columns]

# %%
m_df.columns
# Out:
# Index(['Drug', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'], dtype='object')

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
m_sem = pd.DataFrame(combined_df.groupby(["Drug", "Timepoint"]).sem()["Metastatic Sites"])

m_sem.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
m_sem.reset_index()
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames

# mm_df = m_df.pivot(index="Timepoint", columns="Drug")
m_df.columns
# Preview that Reformatting worked
# mm_df.head()


# # Minor Data Munging to Re-Format the Data Frames
# dm_df = tumor_vol_df.pivot(index="Timepoint", columns="Drug")

# # Preview that Reformatting worked
# dm_df.head()
# Out:
# Index(['Metastatic Sites'], dtype='object')

# %%
# WHY IS THE ONE BELOW SO DIFFERENT TO MINE?!!?
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots()
ax.errorbar(m_df["Timepoint"], m_df["Metastatic Sites"], yerr=m_sem["Metastatic Sites"])

# Save the Figure

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timepoint'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-54aede1b55fc> in <module>
# ...

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
# count_mice = dm_df.value_counts()
# Convert to DataFrame
count_mice = grouped_df['Timepoint'].count()
count_mice_df = pd.DataFrame(count_mice)
mouse_count_df = count_mice_df.rename(columns={"Drug": "Drug", "Timepoint":"Timepoint (days)", "Timepoint": "Mouse Count"})


# I CAN'T GET IT TO EDIT THE COLUMN NAMES FOR DRUG & TIMEPOINT BC I GROUPED BY THEM..??


# Preview DataFrame
# count_mice_df.head()
mouse_count_df.head()
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23

# %%
# Minor Data Munging to Re-Format the Data Frames
count_mice_df_m = count_mice_df.unstack(level = 0)
count_mice_df_m.columns = count_mice_df_m.columns.get_level_values(1)

# Preview that Reformatting worked
count_mice_df_m.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots()
ax.errorbar(count_mice_df_m["Timepoint"], count_mice_df_m["Drug"])


# Save the Figure

# Show the Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timepoint'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-5266ded0b34b> in <module>
# ...

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
perc_df = combined_df.groupby(["Drug"])
# perc_df = combined_df.set_index("Drug")
perc_df.head()
# perc_df.groupby(["Drug"])
# perc_df

# Display the data to confirm
# Out:
#      Mouse ID       Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234   Stelasyn          0           45.000000                 0
# 1        f234   Stelasyn          5           47.313491                 0
# 2        f234   Stelasyn         10           47.904324                 0
# 3        f234   Stelasyn         15           48.735197                 1
# 4        f234   Stelasyn         20           51.112713                 2
# 54       g989   Propriva          0           45.000000                 0
# 55       g989   Propriva          0           45.000000                 0
# 56       g989   Propriva          5           48.786801                 0
# 57       g989   Propriva          5           47.570392                 0
# 58       g989   Propriva         10           51.745156                 0
# 207      j755   Naftisol          0           45.000000                 0
# 208      j755   Naftisol          5           47.242844                 0
# ...

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 
# plt.bar("each drug, x axis...", "Drug volume % change", color='r', alpha=0.5, align="center")
# or:
# perc_df.plot(kind='bar', facecolor='red')
# REFER TO YOUTUBE VIDEO ON BATTLING KINGS TO SEE THIS!
# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)

# %%
# Concluding thoughts/summary:
# Overall the trends indicate that Capomulin and Ramicane are the only drugs that showed efficacy in reducing 
# the volume of tumors found in the tested mice.

# Capomulin and Ramicane also produced the highest survival rates in the days following the start of treatment. 

# there is reason to believe that lower tumor volumes is correlated with greater life expectancy. Since
# Ramicane and Capomulin appear to reduce the tumor volume found in mice, there is reason to believe this is the
# reason why survival rates are also higher for these drugs.

# However, none of the drugs had a large enough sample size of mice for these results to be statistically 
# significant, given that n<40 for every single drug in terms of the number of mice observed. This impairs
# our ability to draw firm conclusions from the test data.
